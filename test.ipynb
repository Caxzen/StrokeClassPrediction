# %%
import pandas as pd
data = pd.io.stata.read_stata('nihss-etumed-data.dta')
data.to_csv('my_stata_file.csv')

# %%
df = pd.read_csv("my_stata_file.csv")
df
# Out:
#     Unnamed: 0  responseid       group               start_date  \
# 0            0          42  E-Learning  2020-04-30 09:05:13.728
# 1            1          21       Video  2020-04-29 07:12:01.536
# 2            2         900       Video                      NaN
# 3            3         131  E-Learning  2020-05-20 07:45:17.312
# 4            4         109  E-Learning  2020-05-13 13:22:16.192
# ..         ...         ...         ...                      ...
# 70          70          30       Video  2020-04-29 11:07:57.312
# 71          71          41  E-Learning  2020-04-30 08:39:00.864
# 72          72          26  E-Learning  2020-04-29 09:12:10.496
# 73          73          27       Video  2020-04-29 09:14:21.568
# 74          74         141       Video  2020-05-21 13:27:52.064
#
#                  quiz_start                 end_date  quiz_time   age  \
# 0   2020-04-30 12:58:30.999  2020-04-30 13:33:55.584       34.0  24.0
# ...
